# %%
# Import Library
import numpy as np # linear algebra
import pandas as pd # data processing, pembacaan file excel
import matplotlib.pyplot as plt # untuk plotting
import datetime  # untuk mengganti format tanggal

# %%
# Pembacaan File Data Polusi Udara ISPU Excel
DKI1 = pd.read_excel("D:\Data\Kuliah\TA\Projek-TA\DATA\Imputer\DATA ISPU - Impute.xlsx", sheet_name="DKI1")
DKI2 = pd.read_excel("D:\Data\Kuliah\TA\Projek-TA\DATA\Imputer\DATA ISPU - Impute.xlsx", sheet_name="DKI2")
DKI3 = pd.read_excel("D:\Data\Kuliah\TA\Projek-TA\DATA\Imputer\DATA ISPU - Impute.xlsx", sheet_name="DKI3")
DKI4 = pd.read_excel("D:\Data\Kuliah\TA\Projek-TA\DATA\Imputer\DATA ISPU - Impute.xlsx", sheet_name="DKI4")
DKI5 = pd.read_excel("D:\Data\Kuliah\TA\Projek-TA\DATA\Imputer\DATA ISPU - Impute.xlsx", sheet_name="DKI5")

# %%
# Menampilkan 6 Data pertama DKI1
DKI1.head(20)
# Out:
#       Tanggal             Wilayah       PM10        SO2         CO         O3
# 0  2017-01-01  DKI1 (Bunderan HI)  63.000000  34.000000  25.000000  21.000000  \
# 1  2017-01-02  DKI1 (Bunderan HI)  16.000000  32.000000  16.000000  19.000000
# 2  2017-01-03  DKI1 (Bunderan HI)  18.000000  32.000000  17.000000  20.000000
# 3  2017-01-04  DKI1 (Bunderan HI)  24.000000  32.000000  22.000000  20.000000
# 4  2017-01-05  DKI1 (Bunderan HI)  29.000000  32.000000  25.000000  14.000000
# 5  2017-01-06  DKI1 (Bunderan HI)  21.000000  31.000000  24.000000  18.000000
# 6  2017-01-07  DKI1 (Bunderan HI)  30.000000  32.000000  22.000000  17.000000
# 7  2017-01-08  DKI1 (Bunderan HI)  29.000000  33.000000  17.000000  19.000000
# 8  2017-01-09  DKI1 (Bunderan HI)  29.000000  32.000000  23.000000  13.000000
# 9  2017-01-10  DKI1 (Bunderan HI)  38.000000  32.000000  34.000000  21.000000
# 10 2017-01-11  DKI1 (Bunderan HI)  25.000000  32.000000  25.000000  20.000000
# 11 2017-01-12  DKI1 (Bunderan HI)  29.000000  32.000000  23.000000  17.000000
# 12 2017-01-13  DKI1 (Bunderan HI)  29.000000  32.000000  19.000000  12.000000
# 13 2017-01-14  DKI1 (Bunderan HI)  22.000000  31.000000  17.000000  13.000000
# 14 2017-01-15  DKI1 (Bunderan HI)  27.000000  32.000000  16.000000  17.000000
# 15 2017-01-16  DKI1 (Bunderan HI)  48.595409  21.978313  16.604986  40.004852
# 16 2017-01-17  DKI1 (Bunderan HI)  48.595409  21.978313  16.604986  40.004852
# 17 2017-01-18  DKI1 (Bunderan HI)  24.000000  28.000000  19.000000  14.000000
# 18 2017-01-19  DKI1 (Bunderan HI)  24.000000  18.600000  16.000000  14.000000
# 19 2017-01-20  DKI1 (Bunderan HI)  18.000000  16.000000  15.000000  10.000000
#
#           NO2        Max Critical        Kategori
# 0    2.000000  63.000000     PM10          SEDANG
# 1    1.000000  32.000000      SO2            BAIK
# 2    2.000000  32.000000      SO2            BAIK
# 3    2.000000  32.000000      SO2            BAIK
# 4    2.000000  32.000000      SO2            BAIK
# 5    2.000000  31.000000      SO2            BAIK
# 6    3.000000  32.000000      SO2            BAIK
# 7    2.000000  33.000000      SO2            BAIK
# 8    2.000000  32.000000      SO2            BAIK
# 9    4.000000  38.000000     PM10            BAIK
# 10   2.000000  32.000000      SO2            BAIK
# 11   2.000000  32.000000      SO2            BAIK
# 12   1.000000  32.000000      SO2            BAIK
# 13   1.000000  31.000000      SO2            BAIK
# 14   1.000000  32.000000      SO2            BAIK
# 15  12.565386  58.417697      NaN  TIDAK ADA DATA
# 16  12.565386  58.417697      NaN  TIDAK ADA DATA
# 17   1.000000  28.000000      SO2            BAIK
# 18   1.000000  24.000000     PM10            BAIK
# 19   1.000000  18.000000     PM10            BAIK

# %%
# Deklarasi variabel untuk data yang akan divisualisasi
Tanggal = DKI1['Tanggal']
PM10 = DKI1['PM10']
SO2 = DKI1['SO2']
Tanggal.head()
# Out:
# 0   2017-01-01
# 1   2017-01-02
# 2   2017-01-03
# 3   2017-01-04
# 4   2017-01-05
# Name: Tanggal, dtype: datetime64[ns]

# %%
# Pengecekan variabel tanggal apakah sudah semuanya tipe datetime64
pd.to_datetime(Tanggal)
# Out:
# 0      2017-01-01
# 1      2017-01-02
# 2      2017-01-03
# 3      2017-01-04
# 4      2017-01-05
#           ...
# 2186   2022-12-27
# 2187   2022-12-28
# 2188   2022-12-29
# 2189   2022-12-30
# 2190   2022-12-31
# Name: Tanggal, Length: 2191, dtype: datetime64[ns]

# %%
# Plot Data
plt.plot(Tanggal, PM10)
